# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\kdura\\Documents\\neuefische\\Capstone\\scripts'

# %%
demo = pd.read_csv("../data/NHANES_2017-2018/demographics.csv")
demo_var = pd.read_excel("../data/NHANES_2017-2018/demographics_variables.xlsx").iloc[:,0:2]

# %%
demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  93703.0      10.0       2.0       2.0       2.0       NaN       5.0
# 1  93704.0      10.0       2.0       1.0       2.0       NaN       3.0
# 2  93705.0      10.0       2.0       2.0      66.0       NaN       4.0
# 3  93706.0      10.0       2.0       1.0      18.0       NaN       5.0
# 4  93707.0      10.0       2.0       1.0      13.0       NaN       5.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDZ  DMDHRMAZ  DMDHSEDZ  \
# 0       6.0       2.0      27.0  ...       3.0       1.0       3.0
# 1       3.0       1.0      33.0  ...       3.0       1.0       2.0
# 2       4.0       2.0       NaN  ...       1.0       2.0       NaN
# 3       6.0       2.0     222.0  ...       3.0       1.0       2.0
# 4       7.0       2.0     158.0  ...       2.0       1.0       3.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
demo_var.head()
# Out:
#   Variable Name                               Variable Description
# 0      AIALANGA     Language of the MEC ACASI Interview Instrument
# 1      DMDBORN4            In what country {were you/was SP} born?
# 2      DMDCITZN  {Are you/Is SP} a citizen of the United States...
# 3      DMDEDUC2  What is the highest grade or level of school {...
# 4      DMDEDUC3  What is the highest grade or level of school {...

# %%
demo_clean = demo.loc[:,["SEQN", "DMDBORN4", "DMDCITZN", "DMDEDUC2","DMDEDUC3","DMDHHSIZ","", "RIAGENDR", "INDFMIN2", "RIDEXPRG"]]

# %%
mapping = dict(zip(demo_var["Variable Name"], demo_var["Variable Description"]))

demo.rename(columns=mapping, inplace = True)

# %%
demo.head()
# Out:
#    Respondent sequence number.  Data release cycle  \
# 0                      93703.0                10.0
# 1                      93704.0                10.0
# 2                      93705.0                10.0
# 3                      93706.0                10.0
# 4                      93707.0                10.0
#
#    Interview and examination status of the participant.  \
# 0                                                2.0
# 1                                                2.0
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#    Gender of the participant.  \
# 0                         2.0
# 1                         1.0
# 2                         2.0
# 3                         1.0
# 4                         1.0
#
#    Age in years of the participant at the time of screening. Individuals 80 and over are topcoded at 80 years of age.  \
# ...
