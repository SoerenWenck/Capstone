# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\srnwn\\Documents\\neueFische\\Capstone\\scripts'

# %%
demo = pd.read_csv("../data/NHANES_2013-2014/demographics.csv")
demo_var = pd.read_excel("../data/NHANES_2013-2014/demographics_variables.xlsx").iloc[:,0:2]
diet = pd.read_csv("../data/NHANES_2013-2014/dietary.csv")
diet_var = pd.read_excel("../data/NHANES_2013-2014/dietary_variables.xlsx").iloc[:,0:2]
exam = pd.read_csv("../data/NHANES_2013-2014/examination.csv")
exam_var = pd.read_excel("../data/NHANES_2013-2014/examination_variables.xlsx")
lab = pd.read_csv("../data/NHANES_2013-2014/laboratory.csv")
lab_var = pd.read_excel("../data/NHANES_2013-2014/laboratory_variables.xlsx")
quest = pd.read_csv("../data/NHANES_2013-2014/questionnaire.csv")
quest_var = pd.read_excel("../data/NHANES_2013-2014/questionnaire_variables.xlsx")

# %%
demo.loc[:,"DMDBORN4"].nunique()
# Out:
# 4

# %%
demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  73557.0       8.0       2.0       1.0      69.0       NaN       4.0
# 1  73558.0       8.0       2.0       1.0      54.0       NaN       3.0
# 2  73559.0       8.0       2.0       1.0      72.0       NaN       3.0
# 3  73560.0       8.0       2.0       1.0       9.0       NaN       3.0
# 4  73561.0       8.0       2.0       2.0      73.0       NaN       3.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       4.0       1.0       NaN  ...       3.0       4.0       NaN
# 1       3.0       1.0       NaN  ...       3.0       1.0       1.0
# 2       3.0       2.0       NaN  ...       4.0       1.0       3.0
# 3       3.0       1.0     119.0  ...       3.0       1.0       4.0
# 4       3.0       1.0       NaN  ...       5.0       1.0       5.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# 0  13281.237386  13481.042095      1.0     112.0       4.0       4.0      0.84
# 1  23682.057386  24471.769625      1.0     108.0       7.0       7.0      1.78
# 2  57214.803319  57193.285376      1.0     109.0      10.0      10.0      4.51
# 3  55201.178592  55766.512438      2.0     109.0       9.0       9.0      2.52
# 4  63709.667069  65541.871229      2.0     116.0      15.0      15.0      5.00
#
# [5 rows x 47 columns]

# %%
demo_var.head(5)
# Out:
#   Variable Name                               Variable Description
# 0      AIALANGA     Language of the MEC ACASI Interview Instrument
# 1      DMDBORN4            In what country {were you/was SP} born?
# 2      DMDCITZN  {Are you/Is SP} a citizen of the United States...
# 3      DMDEDUC2  What is the highest grade or level of school {...
# 4      DMDEDUC3  What is the highest grade or level of school {...

# %%
demo_clean = demo.loc[:,["SEQN", "DMDBORN4", "DMDCITZN", "DMDEDUC2","DMDEDUC3","DMDHHSIZ", "RIAGENDR", "INDFMIN2", "RIDEXPRG"]]

# %%
demo_clean
# Out:
#           SEQN  DMDBORN4  DMDCITZN  DMDEDUC2  DMDEDUC3  DMDHHSIZ  RIAGENDR  \
# 0      73557.0       1.0       1.0       3.0       NaN       3.0       1.0
# 1      73558.0       1.0       1.0       3.0       NaN       4.0       1.0
# 2      73559.0       1.0       1.0       4.0       NaN       2.0       1.0
# 3      73560.0       1.0       1.0       NaN       3.0       4.0       1.0
# 4      73561.0       1.0       1.0       5.0       NaN       2.0       2.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 10170  83727.0       1.0       1.0       5.0       NaN       5.0       1.0
# 10171  83728.0       1.0       1.0       NaN       NaN       4.0       2.0
# 10172  83729.0       2.0       1.0       5.0       NaN       1.0       2.0
# 10173  83730.0       1.0       1.0       NaN       0.0       4.0       1.0
# 10174  83731.0       1.0       1.0       NaN       5.0       4.0       1.0
#
#        INDFMIN2  RIDEXPRG
# 0           4.0       NaN
# 1           7.0       NaN
# 2          10.0       NaN
# 3           9.0       NaN
# 4          15.0       NaN
# ...         ...       ...
# 10170      77.0       NaN
# 10171       8.0       NaN
# 10172       7.0       2.0
# 10173       6.0       NaN
# 10174      15.0       NaN
#
# [10175 rows x 9 columns]

# %%
diet
# Out:
#           SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  \
# 0      73557.0   16888.327864   12930.890649       1.0      49.0    2.0
# 1      73558.0   17932.143865   12684.148869       1.0      59.0    2.0
# 2      73559.0   59641.812930   39394.236709       1.0      49.0    2.0
# 3      73560.0  142203.069917  125966.366442       1.0      54.0    2.0
# 4      73561.0   59052.357033   39004.892993       1.0      63.0    2.0
# ...        ...            ...            ...       ...       ...    ...
# 10170  83551.0            NaN            NaN       NaN       NaN    NaN
# 10171  83593.0            NaN            NaN       NaN       NaN    NaN
# 10172  83635.0            NaN            NaN       NaN       NaN    NaN
# 10173  83652.0            NaN            NaN       NaN       NaN    NaN
# 10174  83657.0            NaN            NaN       NaN       NaN    NaN
#
#        DRDINT  DR1DBIH  DR1DAY  DR1LANG  ...  DSQTPHOS  DSQTMAGN  DSQTIRON  \
# 0         2.0      6.0     2.0      1.0  ...       NaN       NaN       NaN
# 1         2.0      4.0     1.0      1.0  ...       NaN       NaN       NaN
# 2         2.0     18.0     6.0      1.0  ...       NaN     120.0       NaN
# 3         2.0     21.0     3.0      1.0  ...       NaN       NaN       NaN
# 4         2.0     18.0     1.0      1.0  ...       NaN       NaN       NaN
# ...       ...      ...     ...      ...  ...       ...       ...       ...
# 10170     NaN      NaN     NaN      NaN  ...       NaN      50.0       NaN
# 10171     NaN      NaN     NaN      NaN  ...       NaN       NaN       NaN
# 10172     NaN      NaN     NaN      NaN  ...     100.0     100.0       9.0
# 10173     NaN      NaN     NaN      NaN  ...      20.0      50.0      18.0
# 10174     NaN      NaN     NaN      NaN  ...       NaN       NaN       NaN
#
#        DSQTZINC  DSQTCOPP  DSQTSODI  DSQTPOTA  DSQTSELE  DSQTCAFF  DSQTIODI
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          15.0       2.0       NaN       NaN     110.0       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 10170      15.0       1.0      26.0      40.0      35.0       NaN     150.0
# 10171       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 10172       7.5       0.1       NaN      49.5      25.0       NaN      90.0
# 10173      11.0       0.5       NaN      80.0      55.0       NaN     150.0
# 10174       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [10175 rows x 362 columns]

# %%
mapping = dict(zip(demo_var["Variable Name"], demo_var["Variable Description"]))

demo_clean.rename(columns=mapping, inplace = True)

# %%
demo_clean
# Out:
#        Respondent sequence number.  In what country {were you/was SP} born?  \
# 0                          73557.0                                      1.0
# 1                          73558.0                                      1.0
# 2                          73559.0                                      1.0
# 3                          73560.0                                      1.0
# 4                          73561.0                                      1.0
# ...                            ...                                      ...
# 10170                      83727.0                                      1.0
# 10171                      83728.0                                      1.0
# 10172                      83729.0                                      2.0
# 10173                      83730.0                                      1.0
# 10174                      83731.0                                      1.0
#
#        {Are you/Is SP} a citizen of the United States? [Information about citizenship is being collected by the U.S. Public Health Service to perform health related research. Providing this information is voluntary and is collected under the authority of the Public Health Service Act. There will be no effect on pending immigration or citizenship petitions.]  \
# 0                                                    1.0
# 1                                                    1.0
# 2                                                    1.0
# 3                                                    1.0
# 4                                                    1.0
# ...                                                  ...
# 10170                                                1.0
# 10171                                                1.0
# 10172                                                1.0
# 10173                                                1.0
# 10174                                                1.0
#
#        What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?  \
# 0                                                    3.0
# 1                                                    3.0
# 2                                                    4.0
# 3                                                    NaN
# 4                                                    5.0
# ...                                                  ...
# 10170                                                5.0
# 10171                                                NaN
# 10172                                                5.0
# 10173                                                NaN
# 10174                                                NaN
#
#        What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    3.0
# 4                                                    NaN
# ...                                                  ...
# 10170                                                NaN
# 10171                                                NaN
# 10172                                                NaN
# 10173                                                0.0
# 10174                                                5.0
#
#        Total number of people in the Household  Gender of the participant.  \
# 0                                          3.0                         1.0
# 1                                          4.0                         1.0
# 2                                          2.0                         1.0
# 3                                          4.0                         1.0
# 4                                          2.0                         2.0
# ...                                        ...                         ...
# 10170                                      5.0                         1.0
# 10171                                      4.0                         2.0
# 10172                                      1.0                         2.0
# 10173                                      4.0                         1.0
# 10174                                      4.0                         1.0
#
#        Total family income (reported as a range value in dollars)  \
# 0                                                    4.0
# 1                                                    7.0
# 2                                                   10.0
# 3                                                    9.0
# 4                                                   15.0
# ...                                                  ...
# 10170                                               77.0
# 10171                                                8.0
# 10172                                                7.0
# 10173                                                6.0
# 10174                                               15.0
#
#        Pregnancy status for females between 20 and 44 years of age at the time of MEC exam.
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10170                                                NaN
# 10171                                                NaN
# 10172                                                2.0
# 10173                                                NaN
# 10174                                                NaN
#
# [10175 rows x 9 columns]
