# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/harunabi/Documents/capstone'

# %%
df_demo = pd.read_csv('/Users/harunabi/Documents/capstone/demographics.csv')
df_diet = pd.read_csv('/Users/harunabi/Documents/capstone/dietary.csv')
df_ex = pd.read_csv('/Users/harunabi/Documents/capstone/examination.csv')
df_labor = pd.read_csv('/Users/harunabi/Documents/capstone/laboratory.csv')
df_quest = pd.read_csv('/Users/harunabi/Documents/capstone/questionnaire.csv')
# Out:
# /var/folders/w_/l5_6k0ks44j93c_h19c7c9qh0000gn/T/ipykernel_92851/2385902493.py:3: DtypeWarning: Columns (70,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ex = pd.read_csv('/Users/harunabi/Documents/capstone/examination.csv')
# /var/folders/w_/l5_6k0ks44j93c_h19c7c9qh0000gn/T/ipykernel_92851/2385902493.py:5: DtypeWarning: Columns (758,759,776,777) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_quest = pd.read_csv('/Users/harunabi/Documents/capstone/questionnaire.csv')

# %%
df_demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN  ...       5.0       1.0       3.0
# 1       3.0       1.0       NaN  ...       3.0       3.0       NaN
# 2       3.0       2.0       NaN  ...       3.0       1.0       3.0
# 3       3.0       2.0       NaN  ...       5.0       6.0       NaN
# 4       4.0       2.0       NaN  ...       4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...
